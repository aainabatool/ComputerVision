# %% [markdown]
# <a href="https://colab.research.google.com/github/aainabatool/ComputerVision/blob/main/CV_L11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab: 11**

# %% [markdown]
# ## **Import Libraries**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load Image + Convert to Grayscale**

# %%
# Load the image from files
img = cv2.imread("/content/IMG_3748.jpeg")

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(3023.5), np.float64(4031.5), np.float64(-0.5))

# %% [markdown]
# ## **Set Up Blob Detector Params**

# %%
# Create parameter object
params = cv2.SimpleBlobDetector_Params()

# Detect light or dark blobs
params.filterByColor = False

# Filter by area (required)
params.filterByArea = True
params.minArea = 100
params.maxArea = 5000

# Disable other strict filters (optional)
params.filterByCircularity = False
params.filterByConvexity = False
params.filterByInertia = False

# Create the blob detector
detector = cv2.SimpleBlobDetector_create(params)

# %% [markdown]
# ## **Detect Blobs**

# %%
# Detect keypoints
keypoints = detector.detect(gray)

print("Total blobs detected:", len(keypoints))
# Out:
# Total blobs detected: 415

# %% [markdown]
# ## **Draw Detected Blobs & Display Results**

# %%
# Draw red circles around blobs
blobs = cv2.drawKeypoints(
    img, keypoints, np.zeros((1,1)),
    (0,0,255),
    cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS
)

# Show side-by-side
plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Detected Blobs")
plt.imshow(cv2.cvtColor(blobs, cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.show()
